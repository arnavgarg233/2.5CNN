# %%
import torch
from models import MODELS
from utils import load_checkpoint
ckpt_path = 'outputs/main_model'

model = MODELS['custom_resnet'](num_classes=5)
model = load_checkpoint(model, model_path)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 2
#       1 import torch
# ----> 2 from models import MODELS
#       3 from utils import load_checkpoint
#       4 ckpt_path = 'outputs/main_model'
#
# File /workspace/new/ct_severity/models.py:1
# ----> 1 from models2d import *
#       2 from models3d import *
#       3 import torch.optim as optim
#
# File /workspace/new/ct_severity/models2d.py:6
#       4 import numpy as np
#       5 import torchvision.models as models
# ----> 6 from tqdm import tqdm
#       8 import time
#       9 from torch.utils.data import DataLoader
#
# ModuleNotFoundError: No module named 'tqdm'
